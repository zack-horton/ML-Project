# %%
using Pkg
# Pkg.add("CSV")
# Pkg.add("DataFrames")
# Pkg.add("Gurobi")
# Pkg.add("JuMP")
# Pkg.add("LinearAlgebra")
# Pkg.add("Plots")
# Pkg.add("Clustering")
# Pkg.add("StableRNGs")

# %%
using CSV, DataFrames, Gurobi, JuMP, LinearAlgebra, Plots, Clustering, StableRNGs, Random, Statistics

# %%
function read_data(file, scaling)
    # normalized_root = "./normalized_data"
    # scaled_root = "./scaled_data"
    
    if scaling == "normalized"
        data = CSV.read("./normalized_data/$file", DataFrame)
        for c in names(data, Any)
            data[!, c]= Float64.(data[!, c])
        end
        return data
    elseif scaling == "processed"
        data = CSV.read("./processed_data/$file", DataFrame)
        for c in names(data, Any)
            data[!, c]= Float64.(data[!, c])
        end
        return data
    else
        data = CSV.read("./scaled_data/$file", DataFrame)
        for c in names(data, Any)
            data[!, c]= Float64.(data[!, c])
        end
        return data
    end
end

function k_means_cluster(data, k, seed=0)
    # Documentation: https://clusteringjl.readthedocs.io/en/latest/kmeans.html
    
    data_matrix = Matrix(data)
    kmeans_result = Clustering.kmeans(data_matrix', k; rng=StableRNG(seed))
        # kmeans_result.totalcost (within-cluster sum of square distance)
        # a = assignments(kmeans_result) # get the assignments of points to clusters
        # c = counts(kmeans_result) # get the cluster sizes
        # M = kmeans_result.centers # get the cluster centers
    return kmeans_result
end
# Out:
# k_means_cluster (generic function with 2 methods)

# %%
abalone = read_data("abalone_z.csv", "normalized")
similarity_prediction = read_data("similarity_prediction_z.csv", "normalized")

abalone_raw = read_data("abalone.csv", "processed")
similarity_prediction_raw = read_data("similarity_prediction.csv", "processed")

abalone_scaled = read_data("abalone_mm.csv", "scaled")
similarity_prediction_scaled = read_data("similarity_prediction_mm.csv", "scaled")
# Out:
# 100×17 DataFrame
#  Row │ tanimoto_cdk_Extended  TanimotoCombo  pchembl_distance  target_name_5HT ⋯
#      │ Float64                Float64        Float64           Float64         ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │              0.472838       1.0             0.0930931                 0 ⋯
#    2 │              0.430275       0.866106        0.102102                  0
#    3 │              0.451161       0.863519        0.147147                  0
#    4 │              0.463027       0.854463        0.39039                   0
#    5 │              0.333648       0.849935        0.15015                   0 ⋯
#    6 │              0.544889       0.849935        0.432432                  1
#    7 │              0.351486       0.846701        0.027027                  0
#    8 │              0.417813       0.815653        0.0600601                 1
#    9 │              0.254746       0.796248        0.12012                   0 ⋯
#   10 │              0.53766        0.787193        0.0630631                 0
#   11 │              0.117173       0.767141        0.285285                  1
#   ⋮  │           ⋮                  ⋮               ⋮                  ⋮       ⋱
#   91 │              0.146865       0.28784         0.165165                  0
#   92 │              0.150353       0.210867        0.282282                  1 ⋯
#   93 │              0.15372        0.228331        0.108108                  1
#   94 │              0.187615       0.203752        0.018018                  0
#   95 │              0.190543       0.198577        0.456456                  0
#   96 │              0.269125       0.192755        0.384384                  0 ⋯
#   97 │              0.270367       0.117723        0.00900901                1
#   98 │              0.276288       0.138422        0.141141                  1
#   99 │              0.286413       0.206339        0.570571                  0
#  100 │              0.446792       0.309832        0.402402                  0 ⋯
#                                                   14 columns and 79 rows omitted

# %%
function k_means_cluster(data, k, seed=0)
    # Documentation: https://clusteringjl.readthedocs.io/en/latest/kmeans.html
    
    data_matrix = Matrix(data)
    kmeans_result = Clustering.kmeans(data_matrix', k; rng=StableRNG(seed))
        # kmeans_result.totalcost (within-cluster sum of square distance)
        # a = assignments(kmeans_result) # get the assignments of points to clusters
        # c = counts(kmeans_result) # get the cluster sizes
        # M = kmeans_result.centers # get the cluster centers
    return kmeans_result
end


function kmeans_optimal(data, num_rows, distance, k_max, time_limit, warm_start = true)

    data = data[1:num_rows, :]
    
    n = size(data)[1]
    p = size(data)[2]
    
    observation_range = 1:n
    variable_range = 1:p
    cluster_range = 1:k_max

    model = Model(optimizer_with_attributes(Gurobi.Optimizer, "TimeLimit" => time_limit))
    
    @variable(model,
        c[k in cluster_range, j in variable_range])
    @variable(model,
        z[i in observation_range, k in cluster_range], Bin)

    @variable(model,
        d[i in observation_range, j in variable_range] >= 0)

    if warm_start == true
        data_kmeans = k_means_cluster(data, k_max)
        for k in cluster_range
            for j in variable_range
                set_start_value(c[k,j], data_kmeans.centers[j,k])
            end
    
            assignments_vector = data_kmeans.assignments  
            for i in observation_range
                set_start_value(z[i,k], assignments_vector[i] == k ? 1 : 0)
            end
        end
    end

    
    @constraint(model,
        ensure_assignment[i in observation_range],
        sum( (z[i, k]) for k in cluster_range) == 1)
    
    @constraint(model,
        cluster_numbers[k in cluster_range],
        sum( (z[i, k]) for i in observation_range) >= 1)

    if distance == "manhattan"
        @constraint(model,
            distance_1[i in observation_range, j in variable_range, k in cluster_range],
            d[i, j] >= data[i, j] - c[k, j] - 1000*(1 - z[i, k]))
        @constraint(model,
            distance_2[i in observation_range, j in variable_range, k in cluster_range],
            d[i, j] >= c[k, j] - data[i, j] - 1000*(1 - z[i, k]))
    else
        @constraint(model,
            distance_1[i in observation_range, j in variable_range, k in cluster_range],
            d[i, j] >= (data[i, j] - c[k, j])^2 - 1000*(1 - z[i, k]))
        @constraint(model,
            distance_2[i in observation_range, j in variable_range, k in cluster_range],
            d[i, j] >= (c[k, j] - data[i, j])^2 - 1000*(1 - z[i, k]))
    end
    
    @objective(model,
        Min,
        sum( sum( (d[i, j]) for j in variable_range) for i in observation_range))
    
    optimize!(model)

    return model
end



function get_assignments(model)
    z_values = value.(model[:z])  
    n, k_max = size(z_values)
    assignments = zeros(Int, n)

    for i in 1:n
        for k in 1:k_max
            if z_values[i, k] > 0.5  
                assignments[i] = k
                break
            end
        end
    end

    return assignments
end

function get_centers(model)
    c_values = value.(model[:c])  
    return c_values
end



function evaluate_clustering(data, assignments, centers, distance)
    data_matrix = Matrix(data)
    K = maximum(assignments)
    n, p = size(data_matrix)

    wcssd = zeros(K)

    for k in 1:K
        cluster_obs = data_matrix[assignments .== k, :]
        for i in 1:size(cluster_obs)[1]
            if distance == "manhattan"
                wcssd[k] += sum(abs.(cluster_obs[i, :] .- centers[k, :]))^2
            else
                wcssd[k] += norm(cluster_obs[i, :] .- centers[k, :])^2
            end
        end
    end

    return sum(wcssd)
end


function average_silhouette_score(data, assignments, centers)
    data_matrix = Matrix(data)
    n = size(data_matrix, 1)
    K = maximum(assignments)

    # Function to compute the average distance to points in a given cluster
    function avg_distance_to_cluster(point, cluster_points)
        return mean([norm(point - other_point) for other_point in eachrow(cluster_points)])
    end

    silhouette_scores = zeros(n)

    for i in 1:n
        # Current point and its assigned cluster
        point = data_matrix[i, :]
        cluster = assignments[i]

        # a(i): Average distance to points in the same cluster
        same_cluster_points = data_matrix[assignments .== cluster, :]
        a_i = cluster == 1 ? 0 : avg_distance_to_cluster(point, same_cluster_points)

        # b(i): Minimum average distance to points in other clusters
        b_i = Inf
        for k in 1:K
            if k != cluster
                other_cluster_points = data_matrix[assignments .== k, :]
                b_i = min(b_i, avg_distance_to_cluster(point, other_cluster_points))
            end
        end

        # Silhouette score for point i
        silhouette_scores[i] = (b_i - a_i) / max(a_i, b_i)
    end

    return mean(silhouette_scores)
end
# Out:
# average_silhouette_score (generic function with 1 method)

# %% [markdown]
# # Elbow Method on Data to see Neighborhood of Reasonable k Values

# %%
data_matrix = Matrix(abalone)

measure = []
K_max = 20
for k in 1:K_max
    kmeans_result = Clustering.kmeans(data_matrix', k; rng=StableRNG(k+100))
    push!(measure, sum(kmeans_result.totalcost))
end

plot(1:K_max, measure, xlabel="# of Clusters", ylabel="Within Cluster Sum of Squares", title="Elbow Plot for KMeans Clustering - Abalone", linewidth=2)

# %%
data_matrix = Matrix(similarity_prediction)

measure = []
K_max = 20
for k in 1:K_max
    kmeans_result = Clustering.kmeans(data_matrix', k; rng=StableRNG(k+100))
    push!(measure, sum(kmeans_result.totalcost))
end

plot(1:K_max, measure, xlabel="# of Clusters", ylabel="Within Cluster Sum of Squares", title="Elbow Plot for KMeans Clustering - Similarity_Prediction", linewidth=2)

# %% [markdown]
# ### Abalone: 3-5 clusters
# ### Similarity_Prediction: 3-6 clusters

# %% [markdown]
# # Time vs. WCSS - Abalone (manhattan distances)

# %% [markdown]
# ## Test 1: Small Subset of Abalone Data

# %%
# kmeans_optimal(data, num_rows, distance, k_max, time_limit, warm_start)

data = abalone
subset_parameter = 0.25
num_rows = floor(Int, size(abalone)[1] * subset_parameter)
distance = "manhattan"
k_max = 5
times_tested = [30, 60, 90, 120, 180]

models = []
for time_limit in times_tested
    push!(models, kmeans_optimal(data, num_rows, distance, k_max, time_limit))
end
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1049 rows, 14661 columns and 10440 nonzeros
# Model fingerprint: 0xabeb3380
# Model has 93960 quadratic constraints
# Variable types: 9441 continuous, 5220 integer (5220 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e-03, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [1e+03, 1e+03]
#
# User MIP start produced solution with objective 1882.95 (0.04s)
# Loaded user MIP start with objective 1882.95
#
# Presolve added 46980 rows and 45 columns
# Presolve time: 0.22s
# Presolved: 48029 rows, 14706 columns, 195215 nonzeros
# Presolved model has 45 quadratic constraint(s)
# Variable types: 9486 continuous, 5220 integer (5220 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolved: 42809 rows, 13612 columns, 135720 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.02s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 0.000000e+00, 4033 iterations, 0.29 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  690 1882.95171    0.00000   100%     -    1s
#      0     0    0.00000    0 2123 1882.95171    0.00000   100%     -    3s
#      0     0    0.00000    0 2108 1882.95171    0.00000   100%     -    3s
#      0     0          -    0      1882.95171    0.00000   100%     -   10s
#
# Cutting planes:
#   Gomory: 67
#   Implied bound: 2
#   MIR: 3528
#   RLT: 17
#   Relax-and-lift: 1
#
# Explored 1 nodes (29589 simplex iterations) in 10.05 seconds (11.73 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 1882.95
#
# Time limit reached
# Best objective 1.882951707393e+03, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 1387, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 30
# Set parameter TimeLimit to value 30
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1049 rows, 14661 columns and 10440 nonzeros
# Model fingerprint: 0xabeb3380
# Model has 93960 quadratic constraints
# Variable types: 9441 continuous, 5220 integer (5220 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e-03, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [1e+03, 1e+03]
#
# User MIP start produced solution with objective 1882.95 (0.04s)
# Loaded user MIP start with objective 1882.95
#
# Presolve added 46980 rows and 45 columns
# Presolve time: 0.22s
# Presolved: 48029 rows, 14706 columns, 195215 nonzeros
# Presolved model has 45 quadratic constraint(s)
# Variable types: 9486 continuous, 5220 integer (5220 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolved: 42809 rows, 13612 columns, 135720 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.02s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 0.000000e+00, 4033 iterations, 0.27 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  690 1882.95171    0.00000   100%     -    1s
#      0     0    0.00000    0 2123 1882.95171    0.00000   100%     -    3s
#      0     0    0.00000    0 2108 1882.95171    0.00000   100%     -    3s
#      0     0    0.00000    0 1062 1882.95171    0.00000   100%     -   11s
#      0     0    0.00000    0 1637 1882.95171    0.00000   100%     -   13s
#      0     0    0.00000    0 1634 1882.95171    0.00000   100%     -   17s
#      0     0    0.00000    0 2097 1882.95171    0.00000   100%     -   19s
#      0     0    0.00000    0  928 1882.95171    0.00000   100%     -   25s
#      0     0    0.00000    0 2102 1882.95171    0.00000   100%     -   26s
#      0     0    0.00000    0 1710 1882.95171    0.00000   100%     -   30s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 3549
#   RLT: 20
#   Relax-and-lift: 9
#
# Explored 1 nodes (75492 simplex iterations) in 30.04 seconds (33.89 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 1882.95
#
# Time limit reached
# Best objective 1.882951707393e+03, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 3641, time in user-callback 0.01 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 60
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1049 rows, 14661 columns and 10440 nonzeros
# Model fingerprint: 0xabeb3380
# Model has 93960 quadratic constraints
# Variable types: 9441 continuous, 5220 integer (5220 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e-03, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [1e+03, 1e+03]
#
# User MIP start produced solution with objective 1882.95 (0.04s)
# Loaded user MIP start with objective 1882.95
#
# Presolve added 46980 rows and 45 columns
# Presolve time: 0.21s
# Presolved: 48029 rows, 14706 columns, 195215 nonzeros
# Presolved model has 45 quadratic constraint(s)
# Variable types: 9486 continuous, 5220 integer (5220 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolved: 42809 rows, 13612 columns, 135720 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.02s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 0.000000e+00, 4033 iterations, 0.26 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  690 1882.95171    0.00000   100%     -    1s
#      0     0    0.00000    0 2123 1882.95171    0.00000   100%     -    3s
#      0     0    0.00000    0 2108 1882.95171    0.00000   100%     -    4s
#      0     0    0.00000    0 1062 1882.95171    0.00000   100%     -   11s
#      0     0    0.00000    0 1637 1882.95171    0.00000   100%     -   12s
#      0     0    0.00000    0 1634 1882.95171    0.00000   100%     -   17s
#      0     0    0.00000    0 2097 1882.95171    0.00000   100%     -   18s
#      0     0    0.00000    0  928 1882.95171    0.00000   100%     -   25s
#      0     0    0.00000    0 2102 1882.95171    0.00000   100%     -   26s
#      0     0    0.00000    0 1710 1882.95171    0.00000   100%     -   31s
#      0     0    0.00000    0 2108 1882.95171    0.00000   100%     -   33s
#      0     0    0.00000    0 1301 1882.95171    0.00000   100%     -   39s
#      0     0    0.00000    0 2089 1882.95171    0.00000   100%     -   43s
#      0     0    0.00000    0 2083 1882.95171    0.00000   100%     -   48s
#      0     0    0.00000    0 1511 1882.95171    0.00000   100%     -   57s
#      0     0    0.00000    0 2088 1882.95171    0.00000   100%     -   60s
#
# Cutting planes:
#   Gomory: 10
#   MIR: 930
#   RLT: 20
#
# Explored 1 nodes (132881 simplex iterations) in 60.07 seconds (58.18 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 1882.95
#
# Time limit reached
# Best objective 1.882951707393e+03, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 5564, time in user-callback 0.01 sec

# %%
# evaluate_clustering(data, assignments, centers, distance)

assignments = []
centers = []
wcss = []

for i in 1:length(times_tested)
    push!(assignments, get_assignments(models[i]))
    push!(centers, get_centers(models[i]))
    push!(wcss, evaluate_clustering(data[1:num_rows,:], assignments[i], centers[i], distance))
end

scatter(times_tested, wcss, label=false, xlabel="Times Tested", ylabel="WCSS", title="WCSS vs Times Tested", grid=false, color=:blue)
plot!(times_tested, wcss, label="", line=:solid, color=:blue)

# %%
print(wcss_kmeans, "\n")
print(wcss, "\n")
# Out:
# 1882.9517135860033
# Any[11701.735488565871, 11701.735488565871, 10774.976767625478, 10774.976767625478, 10774.976767625478]

# %% [markdown]
# ### Conclusion: Finds optimal after around 90

# %% [markdown]
# # Test 2: Large Subset of Abalone Data

# %%
# kmeans_optimal(data, num_rows, distance, k_max, time_limit, warm_start)

data = abalone
subset_parameter = 0.75
num_rows = floor(Int, size(abalone)[1] * subset_parameter)
distance = "manhattan"
k_max = 5
times_tested = [30, 60, 90, 120, 180]

models = []
for time_limit in times_tested
    push!(models, kmeans_optimal(data, num_rows, distance, k_max, time_limit))
end
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 30
# Set parameter TimeLimit to value 30
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 285017 rows, 43893 columns and 876960 nonzeros
# Model fingerprint: 0xfb719c20
# Variable types: 28233 continuous, 15660 integer (15660 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
#
# User MIP start produced solution with objective 9586.83 (0.12s)
# Loaded user MIP start with objective 9586.83
#
# Presolve time: 0.71s
# Presolved: 285017 rows, 43893 columns, 876960 nonzeros
# Variable types: 28233 continuous, 15660 integer (15660 binary)
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.04s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 12531 iterations, 1.16 seconds (0.76 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0 6264 9586.83319    0.00000   100%     -   12s
#      0     0    0.00000    0 6278 9586.83319    0.00000   100%     -   19s
#      0     0          -    0      9586.83319    0.00000   100%     -   30s
#
# Cutting planes:
#   MIR: 3729
#   RLT: 2223
#   Relax-and-lift: 27
#
# Explored 1 nodes (27927 simplex iterations) in 30.03 seconds (74.57 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 9586.83
#
# Time limit reached
# Best objective 9.586833192038e+03, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 6938, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 60
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 285017 rows, 43893 columns and 876960 nonzeros
# Model fingerprint: 0xfb719c20
# Variable types: 28233 continuous, 15660 integer (15660 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
#
# User MIP start produced solution with objective 9586.83 (0.12s)
# Loaded user MIP start with objective 9586.83
#
# Presolve time: 0.72s
# Presolved: 285017 rows, 43893 columns, 876960 nonzeros
# Variable types: 28233 continuous, 15660 integer (15660 binary)
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.06s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 12531 iterations, 1.24 seconds (0.76 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0 6264 9586.83319    0.00000   100%     -   12s
#      0     0    0.00000    0 6278 9586.83319    0.00000   100%     -   20s
#      0     0    0.00000    0 6262 9586.83319    0.00000   100%     -   31s
#      0     0    0.00000    0 6276 9586.83319    0.00000   100%     -   43s
#
# Cutting planes:
#   MIR: 148
#   RLT: 75
#
# Explored 1 nodes (47003 simplex iterations) in 60.04 seconds (162.99 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 9586.83
#
# Time limit reached
# Best objective 9.586833192038e+03, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 14755, time in user-callback 0.02 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 90
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 285017 rows, 43893 columns and 876960 nonzeros
# Model fingerprint: 0xfb719c20
# Variable types: 28233 continuous, 15660 integer (15660 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
#
# User MIP start produced solution with objective 9586.83 (0.12s)
# Loaded user MIP start with objective 9586.83
#
# Presolve time: 0.72s
# Presolved: 285017 rows, 43893 columns, 876960 nonzeros
# Variable types: 28233 continuous, 15660 integer (15660 binary)
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.04s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 12531 iterations, 1.12 seconds (0.76 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0 6264 9586.83319    0.00000   100%     -   11s
#      0     0    0.00000    0 6278 9586.83319    0.00000   100%     -   19s
#      0     0    0.00000    0 6262 9586.83319    0.00000   100%     -   30s
#      0     0    0.00000    0 6276 9586.83319    0.00000   100%     -   42s
# H    0     0                    9282.5310921    0.00000   100%     -   62s
#      0     0    0.00000    0 6268 9282.53109    0.00000   100%     -   65s
#      0     0    0.00000    0 6260 9282.53109    0.00000   100%     -   79s
#      0     0    0.00000    0 6264 9282.53109    0.00000   100%     -   80s
#      0     0    0.00000    0 6284 9282.53109    0.00000   100%     -   90s
#
# Cutting planes:
#   MIR: 6437
#   RLT: 2088
#   Relax-and-lift: 547
#
# Explored 1 nodes (89910 simplex iterations) in 90.10 seconds (241.65 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 9282.53 9586.83
#
# Time limit reached
# Best objective 9.282531092110e+03, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 17483, time in user-callback 0.01 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 120
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 285017 rows, 43893 columns and 876960 nonzeros
# Model fingerprint: 0xfb719c20
# Variable types: 28233 continuous, 15660 integer (15660 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
#
# User MIP start produced solution with objective 9586.83 (0.12s)
# Loaded user MIP start with objective 9586.83
#
# Presolve time: 0.72s
# Presolved: 285017 rows, 43893 columns, 876960 nonzeros
# Variable types: 28233 continuous, 15660 integer (15660 binary)
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00,
best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 33590, time in user-callback 0.03 sec

# %%
# evaluate_clustering(data, assignments, centers, distance)

assignments = []
centers = []
wcss = []

for i in 1:length(times_tested)
    push!(assignments, get_assignments(models[i]))
    push!(centers, get_centers(models[i]))
    push!(wcss, evaluate_clustering(data[1:num_rows,:], assignments[i], centers[i], distance))
end

scatter(times_tested, wcss, label=false, xlabel="Times Tested", ylabel="WCSS", title="WCSS vs Times Tested", grid=false, color=:blue)
plot!(times_tested, wcss, label="", line=:solid, color=:blue)

# %% [markdown]
# # Time vs. WCSS - Similarity_Prediction (manhattan distances)

# %% [markdown]
# ## Test 1: Small Subset of Similarity_Prediction Data

# %%
# kmeans_optimal(data, num_rows, distance, k_max, time_limit, warm_start)

data = similarity_prediction
subset_parameter = 0.25
num_rows = floor(Int, size(similarity_prediction)[1] * subset_parameter)
distance = "manhattan"
k_max = 3
times_tested = [10,20,30,40,50]

models = []
for time_limit in times_tested
    push!(models, kmeans_optimal(data, num_rows, distance, k_max, time_limit))
end
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2578 rows, 551 columns and 7800 nonzeros
# Model fingerprint: 0xf61a09e0
# Variable types: 476 continuous, 75 integer (75 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
#
# User MIP start produced solution with objective 90.9306 (0.00s)
# Loaded user MIP start with objective 90.9306
#
# Presolve removed 900 rows and 168 columns
# Presolve time: 0.02s
# Presolved: 1678 rows, 383 columns, 5100 nonzeros
# Variable types: 308 continuous, 75 integer (75 binary)
#
# Root relaxation: objective 0.000000e+00, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   44   90.93058    0.00000   100%     -    0s
#      0     0    0.00000    0   52   90.93058    0.00000   100%     -    0s
#      0     0    4.06379    0   47   90.93058    4.06379  95.5%     -    0s
# H    0     0                      85.9149512    4.06379  95.3%     -    0s
#      0     0    6.86188    0   48   85.91495    6.86188  92.0%     -    0s
#      0     0    9.11304    0   48   85.91495    9.11304  89.4%     -    0s
#      0     0   10.16230    0   48   85.91495   10.16230  88.2%     -    0s
#      0     0   10.42497    0   48   85.91495   10.42497  87.9%     -    0s
#      0     0   10.46176    0   46   85.91495   10.46176  87.8%     -    0s
#      0     0   10.46176    0   48   85.91495   10.46176  87.8%     -    0s
#      0     0   10.46176    0   72   85.91495   10.46176  87.8%     -    0s
# H    0     0                      85.8577210   10.46176  87.8%     -    0s
#      0     0   10.46176    0   49   85.85772   10.46176  87.8%     -    0s
#      0     0   10.46176    0   72   85.85772   10.46176  87.8%     -    0s
#      0     0   10.46176    0   72   85.85772   10.46176  87.8%     -    0s
#      0     0   10.46176    0   72   85.85772   10.46176  87.8%     -    0s
#      0     0   10.46176    0   72   85.85772   10.46176  87.8%     -    0s
#      0     0   11.38756    0   72   85.85772   11.38756  86.7%     -    0s
#      0     0   11.38756    0   72   85.85772   11.38756  86.7%     -    0s
#      0     2   11.38756    0   72   85.85772   11.38756  86.7%     -    0s
# H  411   392                      85.6517190   12.59445  85.3%  71.1    0s
# H  507   439                      84.8056063   15.96063  81.2%  66.9    0s
# H  547   510                      83.7330672   15.96063  80.9%  66.5    0s
# H  664   560                      83.0598288   15.96063  80.8%  61.6    0s
# H  677   556                      82.6741537   17.50541  78.8%  62.1    0s
# H  715   600                      82.6519375   17.50541  78.8%  62.6    0s
# H  720   598                      82.3916533   17.50541  78.8%  62.6    0s
# H  727   596                      82.0387495   17.50541  78.7%  62.6    0s
# H  808   652                      81.0387495   18.08824  77.7%  60.6    1s
# H  819   650                      80.4950869   18.08824  77.5%  60.7    1s
# H  873   692                      79.1984145   18.08824  77.2%  60.6    1s
# H  874   687                      78.6372144   18.08824  77.0%  60.7    1s
data = similarity_prediction
subset_parameter = 0.75
num_rows = floor(Int, size(similarity_prediction)[1] * subset_parameter)
distance = "manhattan"
k_max = 3
times_tested = [25,50,75,100,125]

models = []
for time_limit in times_tested
    push!(models, kmeans_optimal(data, num_rows, distance, k_max, time_limit))
end

# %%
# evaluate_clustering(data, assignments, centers, distance)

assignments = []
centers = []
wcss = []

for i in 1:length(times_tested)
    push!(assignments, get_assignments(models[i]))
    push!(centers, get_centers(models[i]))
    push!(wcss, evaluate_clustering(data[1:num_rows,:], assignments[i], centers[i], distance))
end

scatter(times_tested, wcss, label=false, xlabel="Times Tested", ylabel="WCSS", title="WCSS vs Times Tested", grid=false, color=:blue)
plot!(times_tested, wcss, label="", line=:solid, color=:blue)

# %% [markdown]
# # Metric Analysis

# %%
using DataFrames

function run_clustering_cases(datasets, raw_data, proportions, k_values, time_limits, distances)
    results = DataFrame()
    
     for (dataset_name, data) in datasets
        for prop in proportions
            num_rows = floor(Int, size(data)[1] * prop)
            for k in k_values
                for time_limit in time_limits
                    for dist in distances
                        
                        base_result = k_means_cluster(data[1:num_rows, :], k)
                        base_assignments = base_result.assignments
                        base_centers = base_result.centers'
                        base_wcss = evaluate_clustering(data[1:num_rows, :], base_assignments, base_centers, dist)
                        base_silhouette = average_silhouette_score(data[1:num_rows, :], base_assignments, base_centers)
                        
                        base_wcss_raw = evaluate_clustering(raw_data[1:num_rows, :], base_assignments, base_centers, dist)
                        base_silhouette_raw = average_silhouette_score(raw_data[1:num_rows, :], base_assignments, base_centers)
                        # Add to results DataFrame
                        push!(results, (proportion=prop, k=k, time_limit=time_limit, distance=dist, case="Base", WCSS=base_wcss, WCSS_RAW=base_wcss_raw, Silhouette=base_silhouette, Silhouette_RAW=base_silhouette_raw))
    
                        # kmeans_optimal cases
                        for warm_start in [false, true]
                            try
                                optimal_result = kmeans_optimal(data, num_rows, dist, k, time_limit, warm_start)
                                optimal_assignments = get_assignments(optimal_result)
                                optimal_centers = get_centers(optimal_result)
                                optimal_wcss = evaluate_clustering(data[1:num_rows, :], optimal_assignments, optimal_centers, dist)
                                optimal_silhouette = average_silhouette_score(data[1:num_rows, :], optimal_assignments, optimal_centers)
    
                                optimal_wcss_raw = evaluate_clustering(raw_data[1:num_rows, :], optimal_assignments, optimal_centers, dist)
                                optimal_silhouette_raw = average_silhouette_score(raw_data[1:num_rows, :], optimal_assignments, optimal_centers)
                                
                                case_name = warm_start ? "Optimal with Warm Start" : "Optimal without Warm Start"
                                push!(results, (DatasetName=dataset_name, proportion=prop, k=k, time_limit=time_limit, distance=dist, case=case_name, WCSS=optimal_wcss, WCSS_RAW=optimal_wcss_raw, Silhouette=optimal_silhouette, Silhouette_RAW=optimal_silhouette_raw))
                            catch e
                                optimal_wcss = -15095
                                optimal_wcss_raw = -15095
                                optimal_silhouette = -15095
                                optimal_silhouette_raw = -15095
                                
                                case_name = warm_start ? "Optimal with Warm Start" : "Optimal without Warm Start"
                                push!(results, (DatasetName=dataset_name, proportion=prop, k=k, time_limit=time_limit, distance=dist, case=case_name, WCSS=optimal_wcss, WCSS_RAW=optimal_wcss_raw, Silhouette=optimal_silhouette, Silhouette_RAW=optimal_silhouette_raw))
                       
                            end
                        end
                        
                    end
                end
            end
        end
    end

    return results
end
# Out:
# run_clustering_cases (generic function with 2 methods)

# %%
df_abalone = run_clustering_cases([("normalized", abalone), 9"scaled", abalone_raw, [0.10, 0.25, 0.75], [3,4,5], [30, 90, 180], ["manhattan", "euclidean"])
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 5
# Set parameter TimeLimit to value 5
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 172263 rows, 37611 columns and 526176 nonzeros
# Model fingerprint: 0xd1785b94
# Variable types: 28215 continuous, 9396 integer (9396 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 21118.116084
# Presolve time: 0.43s
# Presolved: 172263 rows, 37611 columns, 526176 nonzeros
# Variable types: 28215 continuous, 9396 integer (9396 binary)
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.06s
#
# Barrier statistics:
#  Dense cols : 27
#  AA' NZ     : 2.076e+06
#  Factor NZ  : 7.081e+06 (roughly 140 MB of memory)
#  Factor Ops : 3.335e+08 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.09060876e+08 -4.12797842e+08  8.05e+02 1.96e-11  1.10e+04     2s
#
# Barrier performed 0 iterations in 1.77 seconds (1.11 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.13s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 6267 iterations, 1.02 seconds (0.45 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0 6264 21118.1161    0.00000   100%     -    5s
#
# Explored 1 nodes (8509 simplex iterations) in 5.03 seconds (5.16 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 21118.1
#
# Time limit reached
# Best objective 2.111811532195e+04, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 377, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 5
# Set parameter TimeLimit to value 5
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 172263 rows, 37611 columns and 526176 nonzeros
# Model fingerprint: 0xa7ca073b
# Variable types: 28215 continuous, 9396 integer (9396 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
#
# User MIP start produced solution with objective 11349.7 (0.08s)
# Loaded user MIP start with objective 11349.7
#
# Presolve time: 0.47s
# Presolved: 172263 rows, 37611 columns, 526176 nonzeros
# Variable types: 28215 continuous, 9396 integer (9396 binary)
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.06s
#
# Barrier statistics:
#  Dense cols : 27
#  AA' NZ     : 2.076e+06
#  Factor NZ  : 7.081e+06 (roughly 140 MB of memory)
#  Factor Ops : 3.335e+08 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.65701848e+08 -2.28237919e+08  4.52e+02 1.96e-11  6.12e+03     2s
#
# Barrier performed 0 iterations in 1.64 seconds (1.18 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.09s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 6267 iterations, 0.80 seconds (0.45 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0 6264 11349.6943    0.00000   100%     -    5s
#
# Explored 1 nodes (8491 simplex iterations) in 5.02 seconds (5.14 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 11349.7
#
# Time limit reached
# Best objective 1.134969425115e+04, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 373, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 5
# Set parameter TimeLimit to value 5
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3135 rows, 37611 columns and 18792 nonzeros
# Model fingerprint: 0xc25738e4
# Model has 169128 quadratic constraints
# Variable types: 28215 continuous, 9396 integer (9396 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e-03, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [4e+02, 1e+03]
# Presolve added 84564 rows and 27 columns
# Presolve time: 0.40s
# Presolved: 87699 rows, 37638 columns, 351111 nonzeros
# Presolved model has 27 quadratic constraint(s)
# Variable types: 28242 continuous, 9396 integer (9396 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolved: 78303 rows, 34476 columns, 244296 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.10s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 0.000000e+00, 6260 iterations, 0.61 seconds (0.29 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0 4443          -    0.00000      -     -    5s
#
# Explored 1 nodes (22949 simplex iterations) in 5.01 seconds (16.73 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 0.000000000000e+00, gap -
#
# User-callback calls 386, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 5
# Set parameter TimeLimit to value 5
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3135 rows, 37611 columns and 18792 nonzeros
# Model fingerprint: 0xe7498f16
# Model has 169128 quadratic constraints
# Variable types: 28215 continuous, 9396 integer (9396 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e-03, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [4e+02, 1e+03]
#
# User MIP start produced solution with objective 8439.89 (0.08s)
# Loaded user MIP start with objective 8439.89
#
# Presolve added 84564 rows and 27 columns
# Presolve time: 0.42s
# Presolved: 87699 rows, 37638 columns, 351111 nonzeros
# Presolved model has 27 quadratic constraint(s)
# Variable types: 28242 continuous, 9396 integer (9396 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolved: 78303 rows, 34476 columns, 244296 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.11s
#
# Solved with dual simplex (dual model)
#
# Root relaxation: objective 0.000000e+00, 6260 iterations, 0.62 seconds (0.29 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0 4443 8439.88991    0.00000   100%     -    5s
#
# Explored 1 nodes (22733 simplex iterations) in 5.01 seconds (16.08 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 8439.89
#
# Time limit reached
# Best objective 8.439889905688e+03, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 401, time in user-callback 0.00 sec
# 6×7 DataFrame
#  Row │ proportion  k      time_limit  distance   case                        W ⋯
#      │ Float64     Int64  Int64       String     String                      F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │       0.75      3           5  manhattan  Base                          ⋯
#    2 │       0.75      3           5  manhattan  Optimal without Warm Start
#    3 │       0.75      3           5  manhattan  Optimal with Warm Start
#    4 │       0.75      3           5  euclidean  Base
#    5 │       0.75      3           5  euclidean  Optimal without Warm Start  - ⋯
#    6 │       0.75      3           5  euclidean  Optimal with Warm Start
#                                                                2 columns omitted

# %%
df_similarity = run_clustering_cases([("normalized", similarity_prediction), ("scaled", similarity_prediction_scaled)],similarity_prediction_raw,
    [0.10, 0.25, 0.75], [3,4,5], [30, 90, 180], ["manhattan", "euclidean"])

# %%
df_abalone = run_clustering_cases([("normalized", abalone), ("scaled", abalone_scaled)], abalone_raw, [0.10], [3], [10], ["manhattan", "euclidean"])
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 22938 rows, 5031 columns and 70056 nonzeros
# Model fingerprint: 0x79b3bae9
# Variable types: 3780 continuous, 1251 integer (1251 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 2947.5184610
# Presolve time: 0.04s
# Presolved: 22938 rows, 5031 columns, 70056 nonzeros
# Variable types: 3780 continuous, 1251 integer (1251 binary)
#
# Root relaxation: objective 0.000000e+00, 1181 iterations, 0.09 seconds (0.23 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  828 2947.51846    0.00000   100%     -    0s
# H    0     0                    2917.0189488    0.00000   100%     -    0s
#      0     0    0.00000    0  848 2917.01895    0.00000   100%     -    1s
# H    0     0                    2817.7125809    0.00000   100%     -    1s
#      0     0    4.75009    0  835 2817.71258    4.75009   100%     -    1s
#      0     0   10.92553    0  833 2817.71258   10.92553   100%     -    2s
#      0     0   12.32605    0  833 2817.71258   12.32605   100%     -    2s
#      0     0   17.90641    0  832 2817.71258   17.90641  99.4%     -    4s
#      0     0   17.92804    0  834 2817.71258   17.92804  99.4%     -    4s
#      0     0   19.04488    0  836 2817.71258   19.04488  99.3%     -    5s
#      0     0   19.05212    0  833 2817.71258   19.05212  99.3%     -    5s
#      0     2   19.05212    0  832 2817.71258   19.05212  99.3%     -    6s
# H   31    38                    2772.1583752   19.05212  99.3%  1223    8s
# H   35    38                    2755.6017027   19.05212  99.3%  1219    8s
# H   36    38                    2661.0969834   19.05212  99.3%  1202    8s
# H   37    44                    2451.0436557   19.05212  99.2%  1177    9s
#     60    74   32.03483    8 1030 2451.04366   19.05212  99.2%  1028   10s
#
# Cutting planes:
#   Gomory: 45
#   MIR: 4073
#   RLT: 1739
#   Relax-and-lift: 10
#   PSD: 122
#
# Explored 73 nodes (87813 simplex iterations) in 10.02 seconds (17.39 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 2451.04 2661.1 2755.6 ... 2947.52
#
# Time limit reached
# Best objective 2.451043655735e+03, best bound 1.905211839957e+01, gap 99.2227%
#
# User-callback calls 1569, time in user-callback 0.01 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 22938 rows, 5031 columns and 70056 nonzeros
# Model fingerprint: 0x1464f9ca
# Variable types: 3780 continuous, 1251 integer (1251 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
#
# User MIP start produced solution with objective 1561.43 (0.01s)
# Loaded user MIP start with objective 1561.43
#
# Presolve time: 0.04s
# Presolved: 22938 rows, 5031 columns, 70056 nonzeros
# Variable types: 3780 continuous, 1251 integer (1251 binary)
#
# Root relaxation: objective 0.000000e+00, 1181 iterations, 0.10 seconds (0.23 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  828 1561.43236    0.00000   100%     -    0s
#      0     0    0.00000    0  839 1561.43236    0.00000   100%     -    1s
#      0     0    1.78605    0  834 1561.43236    1.78605   100%     -    1s
#      0     0   11.06181    0  832 1561.43236   11.06181  99.3%     -    2s
# H    0     0                    1527.8827673   11.06181  99.3%     -    2s
#      0     0   15.36693    0  835 1527.88277   15.36693  99.0%     -    2s
#      0     0   17.26607    0  834 1527.88277   17.26607  98.9%     -    3s
#      0     0   17.92804    0  833 1527.88277   17.92804  98.8%     -    4s
#      0     0   20.02646    0  832 1527.88277   20.02646  98.7%     -    6s
#      0     0   20.09298    0  832 1527.88277   20.09298  98.7%     -    6s
#      0     2   20.09298    0  832 1527.88277   20.09298  98.7%     -    6s
#    134   141   92.09478   15  924 1527.88277   20.09298  98.7%   497   10s
#
# Cutting planes:
#   Gomory: 133
#   MIR: 3079
#   RLT: 1295
#   Relax-and-lift: 26
#   PSD: 14
#
# Explored 140 nodes (88193 simplex iterations) in 10.03 seconds (16.19 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 1527.88 1561.43
#
# Time limit reached
# Best objective 1.527882767331e+03, best bound 2.009297915755e+01, gap 98.6849%
#
# User-callback calls 1480, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 420 rows, 5031 columns and 2502 nonzeros
# Model fingerprint: 0x442e4f17
# Model has 22518 quadratic constraints
# Variable types: 3780 continuous, 1251 integer (1251 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [7e-03, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [1e+03, 1e+03]
# Presolve added 11259 rows and 27 columns
# Presolve time: 0.05s
# Presolved: 11679 rows, 5058 columns, 46812 nonzeros
# Presolved model has 27 quadratic constraint(s)
# Variable types: 3807 continuous, 1251 integer (1251 binary)
#
# Root relaxation: objective 0.000000e+00, 1210 iterations, 0.08 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  286          -    0.00000      -     -    0s
#      0     0    0.00000    0  840          -    0.00000      -     -    0s
#      0     0    0.00000    0  840          -    0.00000      -     -    0s
#      0     0    0.00000    0  836          -    0.00000      -     -    1s
#      0     0    0.00000    0  835          -    0.00000      -     -    1s
#      0     0    0.00000    0  703          -    0.00000      -     -    2s
#      0     0    0.00000    0  839          -    0.00000      -     -    2s
#      0     0    0.00000    0  725          -    0.00000      -     -    3s
#      0     0    0.00000    0  843          -    0.00000      -     -    3s
#      0     0    0.00000    0  768          -    0.00000      -     -    5s
#      0     0    0.00000    0  843          -    0.00000      -     -    5s
#      0     0    0.00000    0  504          -    0.00000      -     -   10s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 310
#
# Explored 1 nodes (29618 simplex iterations) in 10.07 seconds (7.48 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 0.000000000000e+00, gap -
#
# User-callback calls 684, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 420 rows, 5031 columns and 2502 nonzeros
# Model fingerprint: 0x158ebf7e
# Model has 22518 quadratic constraints
# Variable types: 3780 continuous, 1251 integer (1251 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [7e-03, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [1e+03, 1e+03]
#
# User MIP start produced solution with objective 1062.6 (0.01s)
# Loaded user MIP start with objective 1062.6
#
# Presolve added 11259 rows and 27 columns
# Presolve time: 0.05s
# Presolved: 11679 rows, 5058 columns, 46812 nonzeros
# Presolved model has 27 quadratic constraint(s)
# Variable types: 3807 continuous, 1251 integer (1251 binary)
#
# Root relaxation: objective 0.000000e+00, 1210 iterations, 0.08 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  286 1062.59704    0.00000   100%     -    0s
#      0     0    0.00000    0  846 1062.59704    0.00000   100%     -    0s
#      0     0    0.00000    0  844 1062.59704    0.00000   100%     -    1s
#      0     0    0.00000    0  477 1062.59704    0.00000   100%     -    2s
#      0     0    0.00000    0  838 1062.59704    0.00000   100%     -    2s
#      0     0    0.00000    0  833 1062.59704    0.00000   100%     -    2s
#      0     0    0.00000    0  824 1062.59704    0.00000   100%     -    2s
#      0     0    0.00000    0  369 1062.59704    0.00000   100%     -    3s
#      0     0    0.00000    0  792 1062.59704    0.00000   100%     -    3s
#      0     0    0.00000    0  589 1062.59704    0.00000   100%     -    4s
#      0     0    0.00000    0  842 1062.59704    0.00000   100%     -    5s
#      0     0    0.00000    0  545 1062.59704    0.00000   100%     -    6s
#      0     0    0.00000    0  680 1062.59704    0.00000   100%     -    6s
#      0     0    0.00000    0  394 1062.59704    0.00000   100%     -    7s
#      0     0    0.00000    0  838 1062.59704    0.00000   100%     -    8s
#      0     0    0.00000    0  727 1062.59704    0.00000   100%     -    9s
#      0     0    0.00000    0  492 1062.59704    0.00000   100%     -   10s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 68
#   Relax-and-lift: 1
#
# Explored 1 nodes (51846 simplex iterations) in 10.01 seconds (11.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 1062.6
#
# Time limit reached
# Best objective 1.062597044166e+03, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 1184, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 22938 rows, 5031 columns and 70056 nonzeros
# Model fingerprint: 0x3d0fa573
# Variable types: 3780 continuous, 1251 integer (1251 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 1246.1982424
# Presolve time: 0.04s
# Presolved: 22938 rows, 5031 columns, 70056 nonzeros
# Variable types: 3780 continuous, 1251 integer (1251 binary)
#
# Root relaxation: objective 0.000000e+00, 1263 iterations, 0.11 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  830 1246.19824    0.00000   100%     -    0s
# H    0     0                     544.8587197    0.00000   100%     -    0s
#      0     0    0.00000    0  834  544.85872    0.00000   100%     -    1s
# H    0     0                     528.4350376    0.00000   100%     -    1s
#      0     0    0.13194    0  834  528.43504    0.13194   100%     -    1s
# H    0     0                     494.0615754    0.20337   100%     -    1s
#      0     0    0.33965    0  832  494.06158    0.33965   100%     -    2s
#      0     0    0.33965    0  833  494.06158    0.33965   100%     -    2s
# H    0     0                     493.8166358    1.00000   100%     -    3s
#      0     0    1.00000    0  833  493.81664    1.00000   100%     -    3s
#      0     0    1.13194    0  837  493.81664    1.13194   100%     -    3s
#      0     0    1.29529    0  834  493.81664    1.29529   100%     -    4s
#      0     0    1.31744    0  833  493.81664    1.31744   100%     -    4s
# H    0     0                     493.7326787    1.36187   100%     -    5s
# H    0     0                     493.5620272    1.36187   100%     -    5s
#      0     0    1.36187    0  832  493.56203    1.36187   100%     -    5s
#      0     0    1.36187    0  832  493.56203    1.36187   100%     -    5s
#      0     2    1.36187    0  830  493.56203    1.36187   100%     -    5s
# H   32    38                     485.3143274    2.31217   100%   862    7s
# H   34    38                     429.9186250    2.64396  99.4%   857    7s
# H   44    50                     399.8395226    2.91229  99.3%   782    9s
#
# Cutting planes:
#   Gomory: 105
#   MIR: 498
#   RLT: 2965
#   Relax-and-lift: 28
#   PSD: 4
#
# Explored 94 nodes (74254 simplex iterations) in 10.02 seconds (14.61 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 399.84 429.919 485.314 ... 1246.2
#
# Time limit reached
# Best objective 3.998395226293e+02, best bound 3.092803270927e+00, gap 99.2265%
#
# User-callback calls 1625, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 22938 rows, 5031 columns and 70056 nonzeros
# Model fingerprint: 0xf33880a9
# Variable types: 3780 continuous, 1251 integer (1251 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
#
# User MIP start produced solution with objective 266.37 (0.01s)
# Loaded user MIP start with objective 266.37
#
# Presolve time: 0.04s
# Presolved: 22938 rows, 5031 columns, 70056 nonzeros
# Variable types: 3780 continuous, 1251 integer (1251 binary)
#
# Root relaxation: objective 0.000000e+00, 1256 iterations, 0.11 seconds (0.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  830  266.36990    0.00000   100%     -    0s
#      0     0    0.00000    0  836  266.36990    0.00000   100%     -    1s
#      0     0    0.12543    0  850  266.36990    0.12543   100%     -    1s
#      0     0    0.60268    0  841  266.36990    0.60268   100%     -    2s
# H    0     0                     264.0802443    0.60268   100%     -    3s
#      0     0    1.21422    0  838  264.08024    1.21422   100%     -    3s
#      0     0    1.33646    0  833  264.08024    1.33646  99.5%     -    4s
#      0     0    1.35781    0  843  264.08024    1.35781  99.5%     -    5s
#      0     0    1.43560    0  837  264.08024    1.43560  99.5%     -    6s
#      0     0    1.44486    0  851  264.08024    1.44486  99.5%     -    6s
#      0     0    1.47957    0  833  264.08024    1.47957  99.4%     -    7s
#      0     0    1.47957    0  832  264.08024    1.47957  99.4%     -    7s
#      0     2    1.47957    0  830  264.08024    1.47957  99.4%     -    8s
#
# Cutting planes:
#   Gomory: 53
#   MIR: 527
#   RLT: 3577
#   Relax-and-lift: 85
#   PSD: 22
#
# Explored 55 nodes (59972 simplex iterations) in 10.01 seconds (13.36 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 264.08 266.37
#
# Time limit reached
# Best objective 2.640802443478e+02, best bound 2.718940567664e+00, gap 98.9704%
#
# User-callback calls 1314, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 420 rows, 5031 columns and 2502 nonzeros
# Model fingerprint: 0x5cf866d9
# Model has 22518 quadratic constraints
# Variable types: 3780 continuous, 1251 integer (1251 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [2e-03, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [1e+03, 1e+03]
# Presolve added 11259 rows and 27 columns
# Presolve time: 0.05s
# Presolved: 11679 rows, 5058 columns, 46791 nonzeros
# Presolved model has 27 quadratic constraint(s)
# Variable types: 3807 continuous, 1251 integer (1251 binary)
#
# Root relaxation: objective 0.000000e+00, 464 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    -          -    0.00000      -     -    3s
#      0     0    0.00000    0  834          -    0.00000      -     -    3s
#      0     0    0.00000    0  834          -    0.00000      -     -    3s
#      0     0    0.00000    0  834          -    0.00000      -     -    3s
#      0     0    0.00000    0  546          -    0.00000      -     -    4s
#      0     0    0.00000    0  546          -    0.00000      -     -    4s
#      0     0    0.00000    0  830          -    0.00000      -     -    4s
#      0     0    0.00000    0  830          -    0.00000      -     -    4s
#      0     0    0.00000    0  422          -    0.00000      -     -    4s
#      0     0    0.00000    0  590          -    0.00000      -     -    4s
#      0     0    0.00000    0  800          -    0.00000      -     -    4s
#      0     0    0.00000    0  800          -    0.00000      -     -    4s
#      0     0    0.00000    0  412          -    0.00000      -     -    5s
#      0     0    0.00000    0  506          -    0.00000      -     -    5s
#      0     0    0.00000    0  754          -    0.00000      -     -    5s
#      0     0    0.00000    0  780          -    0.00000      -     -    5s
#      0     0    0.00000    0  698          -    0.00000      -     -    5s
#      0     0    0.00000    0  834          -    0.00000      -     -    5s
#      0     0    0.00000    0  422          -    0.00000      -     -    6s
#      0     0    0.00000    0  834          -    0.00000      -     -    6s
#      0     0    0.00000    0  834          -    0.00000      -     -    6s
#      0     0    0.00000    0  332          -    0.00000      -     -    7s
#      0     0    0.00000    0  766          -    0.00000      -     -    7s
#      0     0    0.00000    0  528          -    0.00000      -     -    7s
#      0     0    0.00000    0  828          -    0.00000      -     -    7s
#      0     0    0.00000    0  832          -    0.00000      -     -    8s
#      0     0    0.00000    0  832          -    0.00000      -     -    8s
#      0     0    0.00000    0  438          -    0.00000      -     -    8s
#      0     0    0.00000    0  824          -    0.00000      -     -    9s
#      0     0    0.00000    0  832          -    0.00000      -     -    9s
#      0     0    0.00000    0  618          -    0.00000      -     -    9s
#      0     0    0.00000    0  786          -    0.00000      -     -    9s
#      0     0    0.00000    0  786          -    0.00000      -     -   10s
#
# Cutting planes:
#   MIR: 76
#
# Explored 1 nodes (45014 simplex iterations) in 10.01 seconds (10.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 0.000000000000e+00, gap -
#
# User-callback calls 819, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-20
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 420 rows, 5031 columns and 2502 nonzeros
# Model fingerprint: 0xf7cca582
# Model has 22518 quadratic constraints
# Variable types: 3780 continuous, 1251 integer (1251 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [2e-03, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [1e+03, 1e+03]
#
# User MIP start produced solution with objective 38.7781 (0.01s)
# Loaded user MIP start with objective 38.7781
#
# Presolve added 11259 rows and 27 columns
# Presolve time: 0.05s
# Presolved: 11679 rows, 5058 columns, 46791 nonzeros
# Presolved model has 27 quadratic constraint(s)
# Variable types: 3807 continuous, 1251 integer (1251 binary)
#
# Root relaxation: objective 0.000000e+00, 464 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    -   38.77808    0.00000   100%     -    3s
#      0     0    0.00000    0  834   38.77808    0.00000   100%     -    4s
#      0     0    0.00000    0  834   38.77808    0.00000   100%     -    4s
#      0     0    0.00000    0  834   38.77808    0.00000   100%     -    4s
#      0     0    0.00000    0  834   38.77808    0.00000   100%     -    4s
#      0     0    0.00000    0  264   38.77808    0.00000   100%     -    5s
#      0     0    0.00000    0  628   38.77808    0.00000   100%     -    5s
#      0     0    0.00000    0  834   38.77808    0.00000   100%     -    5s
#      0     0    0.00000    0  834   38.77808    0.00000   100%     -    6s
#      0     0    0.00000    0  422   38.77808    0.00000   100%     -    6s
#      0     0    0.00000    0  826   38.77808    0.00000   100%     -    6s
#      0     0    0.00000    0  820   38.77808    0.00000   100%     -    7s
#      0     0    0.00000    0  684   38.77808    0.00000   100%     -    7s
#      0     0    0.00000    0  408   38.77808    0.00000   100%     -    8s
#      0     0    0.00000    0  754   38.77808    0.00000   100%     -    8s
#      0     0    0.00000    0  754   38.77808    0.00000   100%     -    8s
#      0     0    0.00000    0  792   38.77808    0.00000   100%     -    8s
#      0     0    0.00000    0  800   38.77808    0.00000   100%     -    9s
#      0     0    0.00000    0  218   38.77808    0.00000   100%     -    9s
#      0     0    0.00000    0  476   38.77808    0.00000   100%     -    9s
#      0     0    0.00000    0  680   38.77808    0.00000   100%     -   10s
#
# Cutting planes:
#   MIR: 326
#
# Explored 1 nodes (31779 simplex iterations) in 10.01 seconds (9.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 38.7781
#
# Time limit reached
# Best objective 3.877808199012e+01, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 1278, time in user-callback 0.00 sec
# 12×9 DataFrame
#  Row │ proportion  k      time_limit  distance   case                        W ⋯
#      │ Float64     Int64  Int64       String     String                      F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │        0.1      3          10  manhattan  Base                          ⋯
#    2 │        0.1      3          10  manhattan  Optimal without Warm Start
#    3 │        0.1      3          10  manhattan  Optimal with Warm Start
#    4 │        0.1      3          10  euclidean  Base
#    5 │        0.1      3          10  euclidean  Optimal without Warm Start  - ⋯
#    6 │        0.1      3          10  euclidean  Optimal with Warm Start
#    7 │        0.1      3          10  manhattan  Base
#    8 │        0.1      3          10  manhattan  Optimal without Warm Start
#    9 │        0.1      3          10  manhattan  Optimal with Warm Start       ⋯
#   10 │        0.1      3          10  euclidean  Base
#   11 │        0.1      3          10  euclidean  Optimal without Warm Start  -
#   12 │        0.1      3          10  euclidean  Optimal with Warm Start
#                                                                4 columns omitted
